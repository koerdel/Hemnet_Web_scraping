# %% [markdown]
# # Importera bibliotek

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests

# %%
Adresser = []
Länkar = []

for i in range(1,10):
    try:
        url = f"https://www.hemnet.se/bostader?item_types%5B%5D=bostadsratt&location_ids%5B%5D=925970&new_construction=exclude&page={i}&upcoming=exclude"
        Länk = [i["href"] for i in bs.select("a") if "https://www.hemnet.se/bostad/lagenhet" in i["href"]]
        Adress = [i.text[9:-7] for i in bs.select("h2.listing-card__street-address")]
        
        

        # Gör så att request kommer från en browser (i det här fallet från Mozilla version 5.0)
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
        # Läs info från url
        webpage = urlopen(req).read()
        # skapa en BeatifulSoup
        bs = soup(webpage, "html.parser")
        Länkar.append(Länk)        
        Adresser.append(Adress)


    except:
        break

# %%
Adresser
# Out:
# [[],
#  ['Rörstrandsgatan 18, 5tr',
#   'Teknologgatan 8 B',
#   'Birger Jarlsgatan 115 A, 6tr Vindsvåning',
#   'Frejgatan 55, 3 tr',
#   'Rörstrandsgatan 19',
#   'Döbelnsgatan 16C, vind',
#   'Norra Stationsgatan 115, 3 tr',
#   'Birger Jarlsgatan 117',
#   'Döbelnsgatan 56',
#   'Atlasgatan 9, 4 tr',
#   'Upplandsgatan 30',
#   'Sonja Kovalevskys Gata 2',
#   'Västmannagatan 39',
#   'Hälsingegatan 61',
#   'Hälsingegatan 9 ög',
#   'Norrtullsgatan 20',
#   'Bråvallagatan 3, 5 tr',
#   'Rådmansgatan 46, 4tr',
#   'Gästrikegatan 16A',
#   'Torsgatan 42A, Vån 4',
#   'Hagagatan 5, 1tr',
#   'Upplandsgatan 58',
#   'Hagagatan 17A, 2 tr',
#   'Sveavägen 89',
#   'Emmy Rappes gata 3, 11tr',
#   'Torsgatan 7, 3 tr',
#   'Rådmansgatan 46',
#   'Dannemoragatan 14, 5tr',
#   'Rörstrandsgatan 22A',
#   'Sonja Kovalevskys Gata 11, vån 12',
#   'Tulegatan 42, 3 tr',
#   'Tomtebogatan 34',
#   'Dalagatan 86E, 3tr',
#   'Upplandsgatan 25A',
#   'Gävlegatan 6, 4tr',
#   'Norrbackagatan 17, 2tr.',
#   'Idungatan 6A, 4tr',
#   'Vegagatan 5, 3tr.',
#   'Norrbackagatan 27A, 1 tr.',
#   'Torsplan 8',
#   'Torsplan 8',
#   'Västmannagatan 46',
#   'Eastmansvägen 8A',
#   'Tulegatan 31 B, 3 tr',
#   'Dalagatan 74 A',
#   'Upplandsgatan 41, 3 tr',
#   'Vikingagatan 14B, 4tr',
#   'Luntmakargatan 86 A',
#   'Ynglingagatan 26',
#   'Dannemoragatan 16A',
#   'Västmannagatan 17A, 2 tr'],
#  ['Vikingagatan 21, 2tr',
#   'Eastmansvägen 11',
#   'Dalagatan 86H, 3tr',
#   'Upplandsgatan 33, 4 tr',
#   'Atlasgatan 9, 1tr',
#   'Völundsgatan 11',
#   'Birger Jarlsgatan 104L',
#   'Drottninggatan 112C, 2 tr',
#   'Karlbergsvägen 28',
#   'Markvardsgatan 3',
#   'Falugatan 18, 3tr',
#   'Hagagatan 16, 2tr',
#   'Torsgatan 74, 1 TR',
#   'Bråvallagatan 6, 3 tr',
#   'Dannemoragatan 18, 3 tr',
#   'Frejgatan 19',
#   'Roslagsgatan 29, 3tr',
#   'Nina Einhorns Gata 4',
#   'Sveavägen 97, nb ö.g.',
#   'Karlbergsvägen 33',
#   'Gästrikegatan 2',
#   'Hälsingegatan 8, 3tr, ö.g',
#   'Rörstrandsgatan 56B, 4tr',
#   'Robert Almströmsgatan 7, 1tr',
#   'Sonja Kovalevskys Gata 11, 6 tr',
#   'Dalagatan 86B',
#   'Roslagsgatan 6, 4,5tr',
#   'Norrtullsgatan 36, 4tr',
#   'Vanadisvägen 5, 1½ tr',
#   'Frejgatan 37',
#   'Roslagsgatan 62, 4tr',
#   'Upplandsgatan 53, 4tr',
#   'Västmannagatan 89A, 3tr ö.g',
#   'Döbelnsgatan 89, 4 tr',
#   'Rörstrandsgatan 44, 4,5 av 5 tr',
#   'Rörstrandsgatan 18, 5tr',
#   'Västmannagatan 76',
#   'Norra stationsgatan 117, 1,5 tr',
#   'Sveavägen 87, 1tr',
#   'Roslagsgatan 17, 6 tr VIND',
#   'Sankt Eriksgatan 81',
#   'Tomtebogatan 13',
#   'Torsgatan 46A, 1tr',
#   'Rehnsgatan 17, 4tr',
#   'Ruddammsbacken 28',
#   'Dalagatan 70A',
#   'Robert Almströmsgatan 9A, 2 tr',
#   'Idungatan 3, 4tr',
#   'Tegnérgatan 19',
#   'Sankt Eriksgatan 90, 2tr.'],
#  ['Vikingagatan 7, 2 tr',
#   'Torsgatan 43, 6 tr',
#   'Rödabergsgatan 6, 2 tr',
#   'Väringgatan 27, 1 tr',
#   'Gävlegatan 3, 5tr',
#   'Birkagatan 35',
#   'Hälsingegatan 14C',
#   'Frejgatan 34',
#   'Frejgatan 54A, gårdshus',
#   'Tulegatan 45, 7tr',
#   'Dalagatan 40A',
#   'Norrtullsgatan 43',
#   'Tulegatan 46, 3tr',
#   'Observatoriegatan 21A',
#   'Frejgatan 54A, 3tr ög',
#   'Norrbackagatan 15, 6 tr - vindsvåning',
#   'Torsgatan 58, 3 tr',
#   'Frejgatan 56 - VIND',
#   'Norrbackagatan 16',
#   'Torsplan 8 - Våning 12',
#   'Bråvallagatan 8',
#   'Hagagatan 15 F',
#   'Döbelnsgatan 18, 3 tr',
#   'Falugatan 15',
#   'Surbrunnsgatan 45',
#   'Västmannagatan 55A, 2tr',
#   'Sveavägen 139, 5 tr',
#   'Döbelnsgatan 60, 6+7 tr',
#   'Västmannagatan 52, vån 3',
#   'Upplandsgatan 36, vindslägenhet',
#   'Torsgatan 59, 3tr',
#   'Torsgatan 58, 2tr.',
#   'Tomtebogatan 1A, 4tr.',
#   'Idungatan 5, 2 tr',
#   'Tegnérgatan 18',
#   'Sankt eriksgatan 110, 6tr',
#   'Tre Liljor 6, 3 tr.',
#   'Frejgatan 19A',
#   'Frejgatan 58',
#   'Norrbackagatan 27 B, 1 tr',
#   'Norrbackagatan 60, vån 5/5',
#   'Falugatan 21',
#   'Sveavägen 139, 2tr',
#   'Upplandsgatan 43B, Eget gårdshus!',
#   'Upplandsgatan 37',
#   'Frejgatan 46B',
#   'Karlbergsvägen 57, 4 tr',
#   'Sigtunagatan 11, 2 tr',
#   'Sankt Eriksplan 5',
#   'Rådmansgatan 46, 2 tr']]

# %%
Adresser1 = []
for i in Adresser:
    for j in i:
        Adresser1.append(j)

# %%
len(Adresser1)
# Out:
# 151

# %%
for i in Adresser1:
    if Adresser1.count(i) > 1:
        print(i)
# Out:
# Rörstrandsgatan 18, 5tr
# Torsplan 8
# Torsplan 8
# Rörstrandsgatan 18, 5tr

# %%
listan = list(set(Adresser1))

# %%
len(Adresser1)
# Out:
# 151

# %%
Länkar1 = []
for i in Länkar:
    for j in i:
        Länkar1.append(j)

# %%
len(Länkar1)
# Out:
# 161

# %%
from bs4 import BeautifulSoup as soup

# %% [markdown]
# # Rubriker

# %%
Länkar
# Out:
# [['https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-norra-stationsgatan-115,-3-tr-17495489',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-ostermalm-gardet-stockholms-kommun-furusundsgatan-7,-4tr-17493648',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-hagastaden-stockholms-kommun-nina-einhorns-gata-4-17493299',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-norrmalm-stockholms-kommun-olof-palmes-gata-12,-3-tr-17357498',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-odenplan-stockholms-kommun-karlbergsvagen-11a,-gardshus-17455400',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-kungsholmen-stockholms-kommun-bergsgatan-21-17495760',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-vanadisvagen-26a,-2-tr-17453475',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-odenplan-stockholms-kommun-upplandsgatan-53,-4tr-17477455',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-ostermalm-vasastan-stockholms-kommun-surbrunnsgatan-2-a,-3-tr-17484698',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-tre-liljor-6,-3-tr,-17474216'],
#  ['https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dobelnsgatan-89,-4-tr-17360404',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-teknologgatan-8-b-17496241',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-ostermalm-stockholms-kommun-birger-jarlsgatan-115-a,-6tr-vindsvaning-17496618',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-frejgatan-55,-3-tr-17496615',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-rorstrandsgatan-19-17496415',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dobelnsgatan-16c,-vind-17495796',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-norra-stationsgatan-115,-3-tr-17495489',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-sibirien-stockholms-kommun-birger-jarlsgatan-117-17495943',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-dobelnsgatan-56-17495708',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-atlasgatan-9,-4-tr-17495324',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-upplandsgatan-30-17494974',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-hagastaden-stockholms-kommun-sonja-kovalevskys-gata-2-17495986',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-stockholms-kommun-vastmannagatan-39-17495329',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-hagastaden-vasastan-stockholms-kommun-halsingegatan-61-17495288',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-odenplan-stockholms-kommun-halsingegatan-9-og-17495669',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-norrtullsgatan-20-17495605',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-birkastan-vasastan-stockholms-kommun-bravallagatan-3,-5-tr-17495753',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-norrmalm-stockholms-kommun-radmansgatan-46,-4tr-17496039',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-gastrikegatan-16a-17495906',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-stockholms-kommun-torsgatan-42a,-van-4-17495641',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-hagagatan-5,-1tr-17495904',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-odenplan-stockholms-kommun-upplandsgatan-58-17496036',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-hagagatan-17a,-2-tr-17495798',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-stockholms-kommun-sveavagen-89-17495723',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-hagastaden-vasastan-stockholms-kommun-emmy-rappes-gata-3,-11tr-17495290',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-stockholm-stockholms-kommun-torsgatan-7,-3-tr-17495880',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-norrmalm-city-stockholms-kommun-radmansgatan-46-17495234',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-dannemoragatan-14,-5tr-17495638',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-rorstrandsgatan-22a-17495743',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-hagastaden-stockholms-kommun-sonja-kovalevskys-gata-11,-van-12-17495899',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-sibirien-stockholms-kommun-tulegatan-42,-3-tr-17495979',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-tomtebogatan-34-17495938',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-dalagatan-86e,-3tr-17495876',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-upplandsgatan-25a-17495740',
#   'https://www.hemnet.se/bostad/lagenhet-3,5rum-vasastan-odenplan-stockholms-kommun-gavlegatan-6,-4tr-17495170',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-birkastan-stockholms-kommun-norrbackagatan-17,-2tr,-17495936',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-norrtull-stockholms-kommun-idungatan-6a,-4tr-17495738',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-odenplan-stockholms-kommun-vegagatan-5,-3tr,-17495955',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-norrbackagatan-27a,-1-tr,-17475615',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-hagastaden-stockholms-kommun-torsplan-8-17494374',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-hagastaden-stockholms-kommun-torsplan-8-17494958',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-vastmannagatan-46-17494474',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-eastmansvagen-8a-17494367',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-tulegatan-31-b,-3-tr-17493902',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dalagatan-74-a-17494683',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-upplandsgatan-41,-3-tr-17494855',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-birkastan-stockholms-kommun-vikingagatan-14b,-4tr-17493911',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-luntmakargatan-86-a-17495038',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-ynglingagatan-26-17494444',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-dannemoragatan-16a-17495215',
#   'https://www.hemnet.se/bostad/lagenhet-4,5rum-vasastan-stockholms-kommun-vastmannagatan-17a,-2-tr-17495296'],
#  ['https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-vikingagatan-21,-2tr-17494669',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-eastmansvagen-11-17495415',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-dalagatan-86h,-3tr-17494746',
#   'https://www.hemnet.se/bostad/lagenhet-6rum-vasastan-stockholms-kommun-upplandsgatan-33,-4-tr-17494603',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-atlas-stockholms-kommun-atlasgatan-9,-1tr-17494350',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-s-t-eriksplan-stockholms-kommun-volundsgatan-11-17494656',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-ostermalm-stockholms-kommun-birger-jarlsgatan-104l-17494477',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-stockholm-stockholms-kommun-drottninggatan-112c,-2-tr-17432875',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-karlbergsvagen-28-17494130',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-markvardsgatan-3-17493947',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-falugatan-18,-3tr-17493867',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-hagagatan-16,-2tr-17493876',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-torsgatan-74,-1-tr-17385639',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-birkastan-stockholms-kommun-bravallagatan-6,-3-tr-17493439',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-dannemoragatan-18,-3-tr-17493458',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-frejgatan-19-17458255',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-roslagsgatan-29,-3tr-17493560',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-hagastaden-stockholms-kommun-nina-einhorns-gata-4-17493299',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-odenplan-stockholms-kommun-sveavagen-97,-nb-o,g,-17492862',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-karlbergsvagen-33-17491818',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-gastrikegatan-2-17489515',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-stockholm-vasastan-stockholms-kommun-halsingegatan-8,-3tr,-o,g-17489397',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-rorstrandsgatan-56b,-4tr-17490921',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-robert-almstromsgatan-7,-1tr-17491136',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-hagastaden-vasastan-stockholms-kommun-sonja-kovalevskys-gata-11,-6-tr-17485676',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dalagatan-86b-17482542',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-ostermalm-stockholms-kommun-roslagsgatan-6,-4,5tr-17482059',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-norrtullsgatan-36,-4tr-17481536',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-vanadisvagen-5,-1-tr-17349617',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-frejgatan-37-17477136',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-roslagsgatan-62,-4tr-17477135',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-odenplan-stockholms-kommun-upplandsgatan-53,-4tr-17477455',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-vastmannagatan-89a,-3tr-o,g-17477376',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dobelnsgatan-89,-4-tr-17360404',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-birkastan-stockholms-kommun-rorstrandsgatan-44,-4,5-av-5-tr-17478341',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-birkastan-stockholms-kommun-rorstrandsgatan-18,-5tr-17476575',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-vastmannagatan-76-17317239',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-norra-stationsgatan-117,-1,5-tr-17476697',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-sveavagen-87,-1tr-17476403',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-sibirien-stockholms-kommun-roslagsgatan-17,-6-tr-vind-17476775',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-stockholms-kommun-sankt-eriksgatan-81-17423343',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-birkastan-stockholms-kommun-tomtebogatan-13-17476776',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-torsgatan-46a,-1tr-17473364',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-rehnsgatan-17,-4tr-17475923',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-ostermalm-stockholms-kommun-ruddammsbacken-28-17475721',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-dalagatan-70a-17476178',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-robert-almstromsgatan-9a,-2-tr-17475877',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-vasastan-stockholms-kommun-idungatan-3,-4tr-17339602',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-norrmalm-vasastan-stockholms-kommun-tegnergatan-19-17475746',
#   'https://www.hemnet.se/bostad/lagenhet-3,5rum-vasastan-s-t-eriksplan-stockholms-kommun-sankt-eriksgatan-90,-2tr,-17386859'],
#  ['https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-vikingagatan-7,-2-tr-17475680',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-torsgatan-43,-6-tr-17475939',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-rodabergsgatan-6,-2-tr-17475960',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-varinggatan-27,-1-tr-17476078',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-gavlegatan-3,-5tr-17476155',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-birkagatan-35-17475622',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-halsingegatan-14c-17475659',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-stockholms-kommun-frejgatan-34-17475678',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-frejgatan-54a,-gardshus-17475777',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-sibirien-stockholms-kommun-tulegatan-45,-7tr-17475637',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-vasaparken-stockholms-kommun-dalagatan-40a-17475737',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-norrtullsgatan-43-17455145',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-tulegatan-46,-3tr-17474455',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-observatoriegatan-21a-17474661',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-odenplan-stockholms-kommun-frejgatan-54a,-3tr-og-17474441',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-birkastan-stockholms-kommun-norrbackagatan-15,-6-tr-vindsvaning-17475118',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-torsgatan-58,-3-tr-17474530',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-odenplan-stockholms-kommun-frejgatan-56-vind-17472458',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-norrbackagatan-16-17472465',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-hagastaden-stockholms-kommun-torsplan-8-vaning-12-17472547',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-birkastan-stockholms-kommun-bravallagatan-8-17395782',
#   'https://www.hemnet.se/bostad/lagenhet-5rum-vasastan-stockholms-kommun-hagagatan-15-f-17473259',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-dobelnsgatan-18,-3-tr-17473799',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-falugatan-15-17474945',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-surbrunnsgatan-45-17475030',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-odenplan-stockholms-kommun-vastmannagatan-55a,-2tr-17475220',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-sveavagen-139,-5-tr-17474751',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-dobelnsgatan-60,-6-7-tr-17473396',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-vastmannagatan-52,-van-3-17472697',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-upplandsgatan-36,-vindslagenhet-17474984',
#   'https://www.hemnet.se/bostad/lagenhet-3,5rum-vasastan-stockholms-kommun-torsgatan-59,-3tr-17474754',
#   'https://www.hemnet.se/bostad/lagenhet-3,5rum-vasastan-s-t-eriksplan-stockholms-kommun-torsgatan-58,-2tr,-17474447',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-tomtebogatan-1a,-4tr,-17360195',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-idungatan-5,-2-tr-17475097',
#   'https://www.hemnet.se/bostad/lagenhet-6rum-vasastan-stockholms-kommun-tegnergatan-18-17474943',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-sankt-eriksgatan-110,-6tr-17474596',
#   'https://www.hemnet.se/bostad/lagenhet-2,5rum-vasastan-stockholms-kommun-tre-liljor-6,-3-tr,-17474216',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-sibirien-stockholms-kommun-frejgatan-19a-17473142',
#   'https://www.hemnet.se/bostad/lagenhet-5rum-vasastan-stockholms-kommun-frejgatan-58-17473221',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-birkastan-stockholms-kommun-norrbackagatan-27-b,-1-tr-17472546',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-birkastan-vasastan-stockholms-kommun-norrbackagatan-60,-van-5-5-16883952',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-roda-bergen-stockholms-kommun-falugatan-21-17471523',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-sveavagen-139,-2tr-17471758',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-odenplan-stockholms-kommun-upplandsgatan-43b,-eget-gardshus-17471742',
#   'https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-norrmalm-stockholms-kommun-upplandsgatan-37-17471576',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-frejgatan-46b-17470396',
#   'https://www.hemnet.se/bostad/lagenhet-1rum-vasastan-stockholms-kommun-karlbergsvagen-57,-4-tr-17468335',
#   'https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-stockholms-kommun-sigtunagatan-11,-2-tr-17465255',
#   'https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-stockholms-kommun-sankt-eriksplan-5-17462858',
#   'https://www.hemnet.se/bostad/lagenhet-1,5rum-norrmalm-vasastan-stockholms-kommun-radmansgatan-46,-2-tr-16884320']]

# %%
len(Länkar)
# Out:
# 4

# %%
Adresser
# Out:
# [[],
#  ['Döbelnsgatan 89, 4 tr',
#   'Teknologgatan 8 B',
#   'Birger Jarlsgatan 115 A, 6tr Vindsvåning',
#   'Frejgatan 55, 3 tr',
#   'Rörstrandsgatan 19',
#   'Döbelnsgatan 16C, vind',
#   'Norra Stationsgatan 115, 3 tr',
#   'Birger Jarlsgatan 117',
#   'Döbelnsgatan 56',
#   'Atlasgatan 9, 4 tr',
#   'Upplandsgatan 30',
#   'Sonja Kovalevskys Gata 2',
#   'Västmannagatan 39',
#   'Hälsingegatan 61',
#   'Hälsingegatan 9 ög',
#   'Norrtullsgatan 20',
#   'Bråvallagatan 3, 5 tr',
#   'Rådmansgatan 46, 4tr',
#   'Gästrikegatan 16A',
#   'Torsgatan 42A, Vån 4',
#   'Hagagatan 5, 1tr',
#   'Upplandsgatan 58',
#   'Hagagatan 17A, 2 tr',
#   'Sveavägen 89',
#   'Emmy Rappes gata 3, 11tr',
#   'Torsgatan 7, 3 tr',
#   'Rådmansgatan 46',
#   'Dannemoragatan 14, 5tr',
#   'Rörstrandsgatan 22A',
#   'Sonja Kovalevskys Gata 11, vån 12',
#   'Tulegatan 42, 3 tr',
#   'Tomtebogatan 34',
#   'Dalagatan 86E, 3tr',
#   'Upplandsgatan 25A',
#   'Gävlegatan 6, 4tr',
#   'Norrbackagatan 17, 2tr.',
#   'Idungatan 6A, 4tr',
#   'Vegagatan 5, 3tr.',
#   'Norrbackagatan 27A, 1 tr.',
#   'Torsplan 8',
#   'Torsplan 8',
#   'Västmannagatan 46',
#   'Eastmansvägen 8A',
#   'Tulegatan 31 B, 3 tr',
#   'Dalagatan 74 A',
#   'Upplandsgatan 41, 3 tr',
#   'Vikingagatan 14B, 4tr',
#   'Luntmakargatan 86 A',
#   'Ynglingagatan 26',
#   'Dannemoragatan 16A',
#   'Västmannagatan 17A, 2 tr'],
#  ['Vikingagatan 21, 2tr',
#   'Eastmansvägen 11',
#   'Dalagatan 86H, 3tr',
#   'Upplandsgatan 33, 4 tr',
#   'Atlasgatan 9, 1tr',
#   'Völundsgatan 11',
#   'Birger Jarlsgatan 104L',
#   'Drottninggatan 112C, 2 tr',
#   'Karlbergsvägen 28',
#   'Markvardsgatan 3',
#   'Falugatan 18, 3tr',
#   'Hagagatan 16, 2tr',
#   'Torsgatan 74, 1 TR',
#   'Bråvallagatan 6, 3 tr',
#   'Dannemoragatan 18, 3 tr',
#   'Frejgatan 19',
#   'Roslagsgatan 29, 3tr',
#   'Nina Einhorns Gata 4',
#   'Sveavägen 97, nb ö.g.',
#   'Karlbergsvägen 33',
#   'Gästrikegatan 2',
#   'Hälsingegatan 8, 3tr, ö.g',
#   'Rörstrandsgatan 56B, 4tr',
#   'Robert Almströmsgatan 7, 1tr',
#   'Sonja Kovalevskys Gata 11, 6 tr',
#   'Dalagatan 86B',
#   'Roslagsgatan 6, 4,5tr',
#   'Norrtullsgatan 36, 4tr',
#   'Vanadisvägen 5, 1½ tr',
#   'Frejgatan 37',
#   'Roslagsgatan 62, 4tr',
#   'Upplandsgatan 53, 4tr',
#   'Västmannagatan 89A, 3tr ö.g',
#   'Döbelnsgatan 89, 4 tr',
#   'Rörstrandsgatan 44, 4,5 av 5 tr',
#   'Rörstrandsgatan 18, 5tr',
#   'Västmannagatan 76',
#   'Norra stationsgatan 117, 1,5 tr',
#   'Sveavägen 87, 1tr',
#   'Roslagsgatan 17, 6 tr VIND',
#   'Sankt Eriksgatan 81',
#   'Tomtebogatan 13',
#   'Torsgatan 46A, 1tr',
#   'Rehnsgatan 17, 4tr',
#   'Ruddammsbacken 28',
#   'Dalagatan 70A',
#   'Robert Almströmsgatan 9A, 2 tr',
#   'Idungatan 3, 4tr',
#   'Tegnérgatan 19',
#   'Sankt Eriksgatan 90, 2tr.'],
#  ['Vikingagatan 7, 2 tr',
#   'Torsgatan 43, 6 tr',
#   'Rödabergsgatan 6, 2 tr',
#   'Väringgatan 27, 1 tr',
#   'Gävlegatan 3, 5tr',
#   'Birkagatan 35',
#   'Hälsingegatan 14C',
#   'Frejgatan 34',
#   'Frejgatan 54A, gårdshus',
#   'Tulegatan 45, 7tr',
#   'Dalagatan 40A',
#   'Norrtullsgatan 43',
#   'Tulegatan 46, 3tr',
#   'Observatoriegatan 21A',
#   'Frejgatan 54A, 3tr ög',
#   'Norrbackagatan 15, 6 tr - vindsvåning',
#   'Torsgatan 58, 3 tr',
#   'Frejgatan 56 - VIND',
#   'Norrbackagatan 16',
#   'Torsplan 8 - Våning 12',
#   'Bråvallagatan 8',
#   'Hagagatan 15 F',
#   'Döbelnsgatan 18, 3 tr',
#   'Falugatan 15',
#   'Surbrunnsgatan 45',
#   'Västmannagatan 55A, 2tr',
#   'Sveavägen 139, 5 tr',
#   'Döbelnsgatan 60, 6+7 tr',
#   'Västmannagatan 52, vån 3',
#   'Upplandsgatan 36, vindslägenhet',
#   'Torsgatan 59, 3tr',
#   'Torsgatan 58, 2tr.',
#   'Tomtebogatan 1A, 4tr.',
#   'Idungatan 5, 2 tr',
#   'Tegnérgatan 18',
#   'Sankt eriksgatan 110, 6tr',
#   'Tre Liljor 6, 3 tr.',
#   'Frejgatan 19A',
#   'Frejgatan 58',
#   'Norrbackagatan 27 B, 1 tr',
#   'Norrbackagatan 60, vån 5/5',
#   'Falugatan 21',
#   'Sveavägen 139, 2tr',
#   'Upplandsgatan 43B, Eget gårdshus!',
#   'Upplandsgatan 37',
#   'Frejgatan 46B',
#   'Karlbergsvägen 57, 4 tr',
#   'Sigtunagatan 11, 2 tr',
#   'Sankt Eriksplan 5',
#   'Rådmansgatan 46, 2 tr']]

# %%
len(Adresser)
# Out:
# 4

# %% [markdown]
# # Färdig kod

# %%
url = "https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-stockholms-kommun-sveavagen-121a,-3-tr-17451982"
# Gör så att request kommer från en browser (i det här fallet från Mozilla version 5.0)
req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
# Läs info från url
webpage = urlopen(req).read()
# skapa en BeatifulSoup
bs = soup(webpage, "html.parser")
[i.text for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-visits-counter.qa-property-visits-counter > div:nth-child(1) > div.property-visits-counter__row-value")]
# Out:
# []

# %%
print(len(lst))
print(len(lst1))
print(len(Rum_lst))
print(len(Kvm_lst))
print(len(Våning_lst))
print(len(Byggår_lst))
print(len(Avgift_lst))
print(len(Premium_lst))
print(len(Pris_m2_lst))
print(len(Pris_lst))
print(len(Mäklare_lst))
# Out:
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161

# %%
lst = []
lst1 = []
Rum_lst = []
Kvm_lst = []
Våning_lst = []
Byggår_lst = []
Avgift_lst = []
Premium_lst = []
Pris_m2_lst = []
Pris_lst = []
Mäklare_lst = []

for i in Länkar1:  
    # Gör så att request kommer från en browser (i det här fallet från Mozilla version 5.0)
    req = Request(i , headers={'User-Agent': 'Mozilla/5.0'})
    # Läs info från url
    webpage = urlopen(req).read()
    # skapa en BeatifulSoup
    bs = soup(webpage, "html.parser")
    test=[i.text[9:-7].replace(u"\xa0", u"") for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-visits-counter.qa-property-visits-counter > div:nth-child(1) > div.property-visits-counter__row-value")]
    test1=[i.text[9:-7] for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-visits-counter.qa-property-visits-counter > div:nth-child(2) > div.property-visits-counter__row-value")]
    Rum = [i.text[0:-4].replace(u",", u".") for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(1) > div:nth-child(3) > dd")]
    Kvm = [i.text[0:-3].replace(u",", u".") for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(1) > div.property-attributes-table__row.qa-living-area-attribute > dd")]
    Våning = [i.text for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(1) > div.property-attributes-table__row.qa-floor-attribute > dd")]
    Byggår = [i.text for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(1) > div:nth-child(5) > dd")]
    Avgift = [i.text[8:-8].replace(u"\xa0", u"") for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(2) > div:nth-child(1)")]
    Premium =[i.text[1:-1] for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-visits-counter.qa-property-visits-counter > div:nth-child(3) > div.property-visits-counter__row-label > div > div")]
    Pris_m2 = [i.text for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-attributes-table > dl:nth-child(2)")]
    Pris = [i.text[0:-3].replace(u"\xa0", u"") for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__content > section > div > div.property-info__price-container > p")]
    Mäklare = [i.text[11:-2] for i in bs.select("#maklarinfo > div > div.broker-card__body > div.broker-card__info > a")]
    
    
    if test:
        lst.append(test[0])
    else:
        lst.append(np.nan)       
    if test1:
        lst1.append(test1[0])
    else:
        lst1.append(np.nan)       
    if Rum:
        Rum_lst.append(Rum[0])
    else:
        Rum_lst.append(np.nan)       
    if Kvm:
        Kvm_lst.append(Kvm[0])
    else:
        Kvm_lst.append(np.nan)     
    if Våning:
        Våning_lst.append(Våning[0])     
    else:
        Våning_lst.append(np.nan)
    if Byggår:
        Byggår_lst.append(Byggår[0])
    else:
        Byggår_lst.append(np.nan)       
    if Avgift:
        Avgift_lst.append(Avgift[0])
    else:
        Avgift_lst.append(np.nan)       
    if Premium:
        Premium_lst.append(Premium[0])
    else:
        Premium_lst.append("Bas")
    if Pris_m2:
        Pris_m2_lst.append(Pris_m2[0])
    else:
        Pris_m2_lst.append(np.nan)
    if Pris:
        Pris_lst.append(Pris[0])
    else:
        Pris_lst.append(np.nan)
    if Mäklare:
        Mäklare_lst.append(Mäklare[0])
    else:
        Mäklare_lst.append(np.nan)

# %%
[i.text[1:-1] for i in bs.select("body > div.listing-container.qa-listing-container > div > div.listing__property-info.qa-property-info > div.property-info__container > div.property-info__attributes-and-description > div.property-attributes.qa-property-attributes > div.property-visits-counter.qa-property-visits-counter > div:nth-child(3) > div.property-visits-counter__row-label > div > div")]
# Out:
# ['Plus']

# %%
pd.set_option('display.max_rows', 1000)

# %%
df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-20da24c655af> in <module>
# ----> 1 df.reset_index()
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_colwidth', 200)

df = pd.DataFrame({'Pris':Pris_lst, 'Antal rum':Rum_lst, 'Kvm':Kvm_lst, 
                   'Avgift':Avgift_lst, 'Antal besök':lst, 'Antal dagar':lst1, 'Kategori':Premium_lst,
                   'Mäklare':Mäklare_lst, 'Länkar':Länkar1})

# %%
df = df.dropna(subset = ["Antal besök"])

# %%
df['Pris'] = df['Pris'].astype(int)
df['Antal rum'] = df['Antal rum'].astype(float)
df['Kvm'] = df['Kvm'].astype(float)
df['Avgift'] = df['Avgift'].astype(int)
df['Antal besök'] = df['Antal besök'].astype(int)
df['Antal dagar'] = df['Antal dagar'].astype(int)
df.insert(1,'Pris/m2',(df['Pris']/df['Kvm']))
df['Pris/m2'] = df['Pris/m2'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-de3b3e8c1682> in <module>
#       5 df['Antal besök'] = df['Antal besök'].astype(int)
#       6 df['Antal dagar'] = df['Antal dagar'].astype(int)
# ----> 7 df.insert(1,'Pris/m2',(df['Pris']/df['Kvm']))
#       8 df['Pris/m2'] = df['Pris/m2'].astype(int)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert Pris/m2, already exists

# %%
df.sort_values(by=['Antal besök'], inplace=True, ascending=False)

# %%
df
# Out:
# <style  type="text/css" >
# </style><table id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Pris</th>        <th class="col_heading level0 col1" >Pris/m2</th>        <th class="col_heading level0 col2" >Antal rum</th>        <th class="col_heading level0 col3" >Kvm</th>        <th class="col_heading level0 col4" >Avgift</th>        <th class="col_heading level0 col5" >Antal besök</th>        <th class="col_heading level0 col6" >Antal dagar</th>        <th class="col_heading level0 col7" >Kategori</th>        <th class="col_heading level0 col8" >Mäklare</th>        <th class="col_heading level0 col9" >Länkar</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54level0_row0" class="row_heading level0 row0" >154</th>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col0" class="data row0 col0" >6995000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col1" class="data row0 col1" >142755</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col2" class="data row0 col2" >2.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col3" class="data row0 col3" >49.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col4" class="data row0 col4" >2337</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col5" class="data row0 col5" >27635</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col6" class="data row0 col6" >9</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col7" class="data row0 col7" >Bas</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col8" class="data row0 col8" >Innerstadsspecialisten Stockholm AB</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row0_col9" class="data row0 col9" ><a href="https://www.hemnet.se/bostad/lagenhet-2rum-vasastan-odenplan-stockholms-kommun-upplandsgatan-43b,-eget-gardshus-17471742">Länk</a></td>
#             </tr>
#             <tr>
#                         <th id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54level0_row1" class="row_heading level0 row1" >145</th>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col0" class="data row1 col0" >13600000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col1" class="data row1 col1" >85000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col2" class="data row1 col2" >6.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col3" class="data row1 col3" >160.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col4" class="data row1 col4" >5677</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col5" class="data row1 col5" >15714</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col6" class="data row1 col6" >9</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col7" class="data row1 col7" >Bas</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col8" class="data row1 col8" >Eklund Stockholm New York</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row1_col9" class="data row1 col9" ><a href="https://www.hemnet.se/bostad/lagenhet-6rum-vasastan-stockholms-kommun-tegnergatan-18-17474943">Länk</a></td>
#             </tr>
#             <tr>
#                         <th id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54level0_row2" class="row_heading level0 row2" >130</th>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col0" class="data row2 col0" >8450000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col1" class="data row2 col1" >109740</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col2" class="data row2 col2" >3.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col3" class="data row2 col3" >77.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col4" class="data row2 col4" >4516</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col5" class="data row2 col5" >13089</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col6" class="data row2 col6" >9</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col7" class="data row2 col7" >Plus</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col8" class="data row2 col8" >FANTASTIC FRANK</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row2_col9" class="data row2 col9" ><a href="https://www.hemnet.se/bostad/lagenhet-3rum-vasastan-hagastaden-stockholms-kommun-torsplan-8-vaning-12-17472547">Länk</a></td>
#             </tr>
#             <tr>
#                         <th id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54level0_row3" class="row_heading level0 row3" >96</th>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col0" class="data row3 col0" >17995000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col1" class="data row3 col1" >130398</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col2" class="data row3 col2" >4.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col3" class="data row3 col3" >138.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col4" class="data row3 col4" >4341</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col5" class="data row3 col5" >10135</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col6" class="data row3 col6" >7</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col7" class="data row3 col7" >Premium</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col8" class="data row3 col8" >Fastighetsbyrån Stockholm - Vasastan</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row3_col9" class="data row3 col9" ><a href="https://www.hemnet.se/bostad/lagenhet-4rum-vasastan-birkastan-stockholms-kommun-rorstrandsgatan-18,-5tr-17476575">Länk</a></td>
#             </tr>
#             <tr>
#                         <th id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54level0_row4" class="row_heading level0 row4" >128</th>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col0" class="data row4 col0" >6995000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col1" class="data row4 col1" >116583</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col2" class="data row4 col2" >2.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col3" class="data row4 col3" >60.000000</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col4" class="data row4 col4" >2301</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col5" class="data row4 col5" >9870</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col6" class="data row4 col6" >9</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col7" class="data row4 col7" >Premium</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col8" class="data row4 col8" >Innerstadsspecialisten S AB</td>
#                         <td id="T_ce2fe0dc_ab92_11eb_9e78_1e2940303a54row4_col9" class="data row4 col9" ><a href="https://www.hemnet.se/bostad/lagenhet-2rum-vasasta

# %%
# Function to convert file path into clickable form.
def fun(path):
    f_url = "Länk"
    # returns the final component of a url
    #f_url = o.path.basename(path)
    # convert the url into link
    return f'<a href="{path}">{f_url}</a>'
df = df.style.format({'Länkar' : fun})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-77ad2d62859d> in <module>
#       6     # convert the url into link
#       7     return f'<a href="{path}">{f_url}</a>'
# ----> 8 df = df.style.format({'Länkar' : fun})
#       9 df
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
df.sort_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-937e54797a99> in <module>
# ----> 1 df.sort_index(inplace=True)
#
# AttributeError: 'Styler' object has no attribute 'sort_index'

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = df[2:10000], x = "Kategori", y = "Antal besök", hue = "Dagar",
            order=["Bas", "Plus", "Premium"], hue_order = ["10 eller färre dagar", "10 eller fler dagar"], palette="viridis")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-c0624d5138b2> in <module>
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.barplot(data = df[2:10000], x = "Kategori", y = "Antal besök", hue = "Dagar",
#       3             order=["Bas", "Plus", "Premium"], hue_order = ["10 eller färre dagar", "10 eller fler dagar"], palette="viridis")
#
# TypeError: 'Styler' object is not subscriptable

# %%
df[1:10000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-0d0509c28360> in <module>
# ----> 1 df[1:10000]
#
# TypeError: 'Styler' object is not subscriptable

# %%
df["Dagar"] = df["Antal dagar"].apply(lambda x: "10 eller färre dagar" if x <= 10 else "10 eller fler dagar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-abf0cd5da1cd> in <module>
# ----> 1 df["Dagar"] = df["Antal dagar"].apply(lambda x: "10 eller färre dagar" if x <= 10 else "10 eller fler dagar")
#
# TypeError: 'Styler' object is not subscriptable

# %%
sns.histplot(data = df[2:1000], x = "Kvm", bins=20)
# Out:
# <AxesSubplot:xlabel='Kvm', ylabel='Count'>

# %%
sns.pieplot(df.Kategori[2:1000], bins=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1477-3e358ecaef4c> in <module>
# ----> 1 sns.pieplot(df.Kategori[2:1000], bins=3)
#
# AttributeError: module 'seaborn' has no attribute 'pieplot'

# %%
summe.plot(kind = "bar", figsize = (12,8), fontsize = 15)
plt.title("Mäklare", fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1434-575aee13d6c5> in <module>
# ----> 1 summer.Medal.plot(kind = "bar", figsize = (12,8), fontsize = 15)
#       2 plt.title("Mäklare", fontsize = 20)
#       3 plt.show()
#
# NameError: name 'summer' is not defined

# %%
plt.figure(figsize=(12,8))
sns.barplot(data = df, x = "Kategori", y = "Antal rum", hue = "Dagar",
            order=["Bas", "Plus", "Premium"], hue_order = ["10 eller färre dagar", "10 eller fler dagar"], palette="viridis")
# Out:
# <AxesSubplot:xlabel='Kategori', ylabel='Antal rum'>

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = ["Bas","Premium","Plus"]
plt.pie(x=df.Kategori.value_counts(), autopct="%.1f%%", labels=labels, pctdistance=0.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbffb3ac760>,
#   <matplotlib.patches.Wedge at 0x7fbffb3ace20>,
#   <matplotlib.patches.Wedge at 0x7fc008ae84f0>],
#  [Text(-0.32590310130231714, 1.05061275861353, 'Bas'),
#   Text(-0.32590319966778125, -1.050612728100275, 'Premium'),
#   Text(0.9068857027343987, -0.6225418236359194, 'Plus')],
#  [Text(-0.14813777331923506, 0.47755125391524095, '59.6%'),
#   Text(-0.14813781803080964, -0.47755124004557953, '21.3%'),
#   Text(0.4122207739701812, -0.2829735561981451, '19.1%')])

# %%
sns.histplot(data = df[2:1000], x = "Kategori", bins=20, shrink=0.8)
# Out:
# <AxesSubplot:xlabel='Kategori', ylabel='Count'>
